# %% [markdown]
# ## Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.figure_factory as ff
import plotly.express as px
from sklearn.metrics.pairwise import linear_kernel
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## Building Intuition

# %% [markdown]
# ### About the Dataset

# %% [markdown]
# This dataset has more than 8000+ movies and Discover unparalleled cinematic excellence in this dataset (top_rated_movies1.csv) – a curated collection of IMDB's highest-rated films. Dive into a world of precision recommendations and elevate your movie experience with this treasure trove of acclaimed masterpieces

# %%
df = pd.read_csv(r'/kaggle/input/all-top-rated-imdb-movies-dataset/Top_rated_movies1.csv')
df
# Out:
#           id                                 title  \
# 0     168705                            BloodRayne
# 1      19766                    Inspector Gadget 2
# 2     248705            The Visitors: Bastille Day
# 3      17711  The Adventures of Rocky & Bullwinkle
# 4        580                     Jaws: The Revenge
# ...      ...                                   ...
# 8826   12142                     Alone in the Dark
# 8827    5491                     Battlefield Earth
# 8828   11059                     House of the Dead
# 8829   14164                  Dragonball Evolution
# 8830   40016            Birdemic: Shock and Terror
#
#                                                overview  popularity  \
# 0     In 18th-century Romania, after spending much o...      17.499
# 1     After capturing Claw, all the criminals have g...      20.772
# 2     Stuck in the corridors of time, Godefroy de Mo...      18.828
# 3     Rocky and Bullwinkle have been living off the ...      16.436
# 4     After another deadly shark attack, Ellen Brody...      30.996
# ...                                                 ...         ...
# 8826  Edward Carnby is a private investigator specia...      12.499
# 8827  In the year 3000, man is no match for the Psyc...      19.133
# 8828  Set on an island off the coast, a techno rave ...      10.795
# 8829  On his 18th birthday, Goku receives a mystical...      38.646
# 8830  A platoon of eagles and vultures attacks the r...      13.853
#
#      release_date  vote_average  vote_count
# 0      2005-10-22         4.105         501
# 1      2003-03-11         4.100         342
# 2      2016-03-23         4.090         636
# 3      2000-06-30         4.075         335
# 4      1987-07-17         4.064         931
# ...           ...           ...         ...
# 8826   2005-01-28         3.228         550
# 8827   2000-05-12         3.221         761
# 8828   2003-04-11         3.100         359
# 8829   2009-03-12         2.891        1925
# 8830   2010-02-27         2.106         306
#
# [8831 rows x 7 columns]

# %%
df.describe()
# Out:
#                  id   popularity  vote_average    vote_count
# count  8.831000e+03  8831.000000   8831.000000   8831.000000
# mean   1.775555e+05    33.136177      6.639059   1969.126486
# std    2.352400e+05    49.108903      0.794924   3059.560533
# min    5.000000e+00     0.600000      2.106000      1.000000
# 25%    9.927500e+03    16.729000      6.113500    469.000000
# 50%    3.387500e+04    23.804000      6.662000    846.000000
# 75%    3.345215e+05    35.751500      7.205000   1966.000000
# max    1.151534e+06  1766.305000      8.708000  34794.000000

# %%
df.columns
# Out:
# Index(['id', 'title', 'overview', 'popularity', 'release_date', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# id              0
# title           0
# overview        1
# popularity      0
# release_date    0
# vote_average    0
# vote_count      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8831 entries, 0 to 8830
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            8831 non-null   int64
#  1   title         8831 non-null   object
#  2   overview      8830 non-null   object
#  3   popularity    8831 non-null   float64
#  4   release_date  8831 non-null   object
#  5   vote_average  8831 non-null   float64
#  6   vote_count    8831 non-null   int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 483.1+ KB

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# Removing the row that has nan value

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (8830, 7)

# %%
df.iloc[0].iloc[0]
# Out:
# 168705

# %%
# Just trimming to avoid unwanted errors
# Movie titles are in the second column.
df['title'] = df['title'].str.strip()

# %% [markdown]
# ## Data Manipulation

# %% [markdown]
# #### Manipulating rows with duplicate ids
# 1. Combining the duplicate rows by taking mean of the numerical values of the features.
# 2. Removing the duplicate rows the entire dataframe.
# 3. Combining both

# %%
duplicate_df = df[df.duplicated('id', keep=False)]
final_df = df
unique_df = df.drop_duplicates('id', keep=False)
print(f'Length of duplicate rows: {len(duplicate_df)}, entire_df: {len(final_df)}, unique_df: {len(unique_df)}')
length_of_final_df = len(final_df) - len(duplicate_df)/2
print(f'Length of the combined df after aggregation should be: {length_of_final_df}')
# Out:
# Length of duplicate rows: 40, entire_df: 8830, unique_df: 8790
# Length of the combined df after aggregation should be: 8810.0

# %%
# Group by 'id' and apply the consistency check
# Check consistency within each group for the specified features i.e., gives the count of unique values for the each features for each id..
consistency_check = duplicate_df.groupby('id')[['vote_count', 'vote_average', 'popularity']].nunique()
# Checks if all the values of the feature in each column is 1
# consistency_check[~(consistency_check == 1).all(axis=1)]
consistent_groups = consistency_check[(consistency_check == 1).all(axis=1)] # unique ids (rows) with same vote_count and vote_average

num_consistent = len(consistent_groups)
num_inconsistent = len(duplicate_df)/2 - len(consistent_groups)

# Create a summary DataFrame
summary_df = pd.DataFrame({
    'Consistency': ['Consistent', 'Inconsistent'],
    'Count': [num_consistent, num_inconsistent]
})

print("Summary of Consistent and Inconsistent Groups:")
print(summary_df)

# Plot the summary using Plotly
fig = px.bar(summary_df, x='Consistency', y='Count', title='Consistency of Duplicate Rows for Specific Features', 
             labels={'Count': 'Number of Groups', 'Consistency': 'Consistency Status'})

# Show plot
fig.show()
# Out:
# Summary of Consistent and Inconsistent Groups:
#     Consistency  Count
# 0    Consistent    0.0
# 1  Inconsistent   20.0
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="e5e302b1-19e3-444f-beea-937f48f3370d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e5e302b1-19e3-444f-beea-937f48f3370d")) {                    Plotly.newPlot(                        "e5e302b1-19e3-444f-beea-937f48f3370d",                        [{"alignmentgroup":"True","hovertemplate":"Consistency Status=%{x}\u003cbr\u003eNumber of Groups=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Consistent","Inconsistent"],"xaxis":"x","y":[0.0,20.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[ ...

# %% [markdown]
# - The above plot shows that duplicate rows with duplicate ids have different vote_count or vote_average or popularity value
# - `Consistency` - By "consistency" in this context, we mean that for duplicate IDs, the values in the specified feature columns are the same across all duplicate rows.

# %% [markdown]
# #### Aggregating duplicate rows

# %%
# Taking mean as aggregate function
aggregated_df = duplicate_df.groupby('id').agg({
    'title': 'first',  # Keep the first title
    'overview': 'first',
    'release_date': 'first',
    'vote_count': 'mean',  # Take the mean of vote_count
    'vote_average': 'mean',  # Take the mean of vote_average
    'popularity': 'mean'  # Take the mean of popularity
}).reset_index()
final_df = pd.concat([unique_df, aggregated_df])

# Ensuring correctness 
print(f'Length of the combined df after aggregation should be: {length_of_final_df}')
print(f'After combining length of the combined df is : {len(final_df)}')
df = final_df
# Out:
# Length of the combined df after aggregation should be: 8810.0
# After combining length of the combined df is : 8810

# %%
df['release_date'] = pd.to_datetime(df['release_date'])
df.dtypes
# Out:
# id                       int64
# title                   object
# overview                object
# popularity             float64
# release_date    datetime64[ns]
# vote_average           float64
# vote_count             float64
# dtype: object

# %%
df['release_year'] = df['release_date'].dt.year
df['release_month'] = df['release_date'].dt.month_name()
df['release_month_no'] = df['release_date'].dt.month

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# **Before getting into EDA let's analyze what the columns are about,**
# - id          : Unique movies id
# - title       : Movies name
# - overview    : Short summary of every movie
# - popularity  : Popularity scale for every movies
# - release_data: Date of movies released
# - vote_average: Average vote scale for movies from 1 to 10
# - vote_count  : Total vote count for each movies

# %% [markdown]
# - Some movies may have same name.

# %%
print(f'No. of unique movie titles: {df["title"].nunique()}')
# Out:
# No. of unique movie titles: 8513

# %%
# Just cross checking
print(f'No. of unique movie ids: {df["id"].nunique()}')
# Out:
# No. of unique movie ids: 8810

# %% [markdown]
# **movie ids > movie titles**
# - Therefore there is a possibility that same movie may be assigned with more than one movie ids.
# - Meaning that there may be more than 1 movies with same name.

# %% [markdown]
# #### Movies with same names

# %%
title_id_counts = df.groupby('title')['id'].nunique()
same_titled_movies = title_id_counts[title_id_counts > 1].index.tolist()
print(f"Titles with multiple IDs: {len(same_titled_movies)}")
# Out:
# Titles with multiple IDs: 270

# %%
df[df['title']=='The Room']
# Out:
#           id     title                                           overview  \
# 8      17473  The Room  Johnny is a successful banker with great respe...
# 5565  582913  The Room  Kate and Matt discover that a part of their ho...
#
#       popularity release_date  vote_average  vote_count  release_year  \
# 8         14.775   2003-06-27         4.035      1298.0          2003
# 5565      20.959   2019-09-12         6.411       850.0          2019
#
#      release_month  release_month_no
# 8             June                 6
# 5565     September                 9

# %%
# Marking the duplicate and unique rows for visualization..
df['title_type'] = df['title'].apply(lambda x: 'Duplicate' if x in same_titled_movies else 'Unique')
title_type_counts = df['title_type'].value_counts()

# %% [markdown]
# ### Visualization

# %% [markdown]
# **Unique vs. Duplicate movie titles**

# %%
plt.figure(figsize=(6,6))
color = sns.color_palette('viridis', len(title_type_counts))
plt.pie(title_type_counts, labels=title_type_counts.index, autopct='%1.1f%%', colors= color, startangle=140)
plt.title('Distribution of Unique vs. Duplicate Titles')
plt.show()

# %% [markdown]
# #### Movies vs release date

# %%
release_year_counts = df['release_year'].value_counts()[:20]

# Plot the pie chart
plt.figure(figsize=(10, 10))
colors = sns.color_palette('viridis', len(release_year_counts))
plt.pie(release_year_counts, labels=release_year_counts.index, autopct='%1.1f%%', colors=colors, startangle=140)
plt.title('Distribution of Movies by Top 20 Release Year')
plt.show()

# %% [markdown]
# #### Correlation between popularity, vote_average, vote_count,

# %%
columns = ['popularity', 'vote_count', 'vote_average']
correlation_matrix = df[columns].corr()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Features')
plt.show()

# %% [markdown]
# #### Visualizing the distribution of popularity

# %% [markdown]
# ***Zoom the plot for better visualization***

# %%
fig = px.histogram(df['popularity'], x='popularity', title='Interactive Histogram of Popularity', color_discrete_sequence=['#1f77b4'])
fig.show()
# Out:
# <div>                            <div id="588701a6-4af1-4a0b-baa0-ab3f4f156a71" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById
.888,7.886,7.886,7.9,7.886,7.9,7.883,7.882,7.882,7.881,7.88,7.881,7.88,7.888,7.881,7.883,7.878,7.878,7.878,7.876,7.874,7.874,7.874,7.9,7.872,7.871,7.87,7.87,7.869,7.869,7.868,7.869,7.868,7.867,7.867,7.865,7.9,7.863,7.861,7.862,7.861,7.86,7.86,7.859,7.858,7.857,7.856,7.856,7.855,7.854,7.854,7.854,7.853,7.853,7.9,7.852,7.849,7.851,7.85,7.85,7.849,7.846,7.847 ...

# %% [markdown]
# #### Top 20 movies with most votes

# %%
# Generating dict for easy access of movie titles using movie_id
id_movie_dict = {}
for i in range(len(df)):
    id_movie_dict[df.iloc[i].iloc[0]] = df.iloc[i].iloc[1]

# Since there are no duplicate rows now... The length of dict shouls be same as the length of the dataframe
print(f' Length of dict: {len(id_movie_dict)}, is the length right?: {len(id_movie_dict)==len(df)}')
# Out:
#  Length of dict: 8810, is the length right?: True

# %%
def plot_top_20(feature: str, df: pd.DataFrame(), id_movie_dict: {}):
    altered_df = df[['id','title',feature]].sort_values(by = feature, ascending=False).head(20)
    fig = px.bar(altered_df, x='title', y = feature, orientation='v', 
                 title=f'Top {20} Movies by {feature}', 
                 labels={'vote_count': feature.title(), 'title': 'Title'})
    fig.show()

# %%
plot_top_20('vote_count', df, id_movie_dict)
# Out:
# <div>                            <div id="43ac8a9b-3cb6-41f9-9a55-d73ca82c7a18" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("43ac8a9b-3cb6-41f9-9a55-d73ca82c7a18")) {                    Plotly.newPlot(                        "43ac8a9b-3cb6-41f9-9a55-d73ca82c7a18",                        [{"alignmentgroup":"True","hovertemplate":"Title=%{x}\u003cbr\u003eVote_Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Inception","Interstellar","The Dark Knight","Avatar","The Avengers","Deadpool","Avengers: Infinity War","Fight Club","Guardians of the Galaxy","Pulp Fiction","Forrest Gump","Harry Potter and the Philosopher's Stone","Iron Man","The Shawshank Redemption","Django Unchained","The Matrix","Avengers: Endgame","Titanic","Joker","The Lord of the Rings: The Fellowship of the Ring"],"xaxis":"x","y":[34794.0,32975.0,30958.0,30044.0,29371.0,29102.0,28003.0,27556.0,26834.0,26185.0,25699.0,25646.0,25076.0,24985.0,24899.0,24108.0,24104.0,23876.0,23683.0,23569.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter" ...

# %% [markdown]
# #### Top 20 popular movies

# %%
plot_top_20('popularity', df, id_movie_dict)
# Out:
# <div>                            <div id="35048103-78c3-4f17-97a0-c5292fb70661" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35048103-78c3-4f17-97a0-c5292fb70661")) {                    Plotly.newPlot(                        "35048103-78c3-4f17-97a0-c5292fb70661",                        [{"alignmentgroup":"True","hovertemplate":"Title=%{x}\u003cbr\u003epopularity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Oppenheimer","The Creator","Five Nights at Freddy's","Expend4bles","Mission: Impossible - Dead Reckoning Part One","Fast X","The Hunger Games: The Ballad of Songbirds & Snakes","The Equalizer 3","Blue Beetle","Saw X","Meg 2: The Trench","The Super Mario Bros. Movie","Elemental","Barbie","Gran Turismo","The Marvels","Transformers: Rise of the Beasts","Spider-Man: Across the Spider-Verse","Avatar: The Way of Water","The Nun II"],"xaxis":"x","y":[1766.305,1622.502,1252.998,873.341,762.172,749.903,595.362,573.141,515.987,509.974,503.411,502.499,491.164,484.841,481.406,480.065,460.082,448.515,422.762,419.542],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillm ...

# %% [markdown]
# #### Top 20 movies with highest vote average

# %%
plot_top_20('vote_average', df, id_movie_dict)
# Out:
# <div>                            <div id="21679eeb-8d35-430c-b178-36e5ec9dd2c2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("21679eeb-8d35-430c-b178-36e5ec9dd2c2")) {                    Plotly.newPlot(                        "21679eeb-8d35-430c-b178-36e5ec9dd2c2",                        [{"alignmentgroup":"True","hovertemplate":"Title=%{x}\u003cbr\u003evote_average=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["The Godfather","The Shawshank Redemption","The Godfather Part II","Schindler's List","Dilwale Dulhania Le Jayenge","12 Angry Men","Spirited Away","Parasite","The Dark Knight","The Green Mile","Your Name.","Pulp Fiction","The Lord of the Rings: The Return of the King","Forrest Gump","The Good, the Bad and the Ugly","GoodFellas","Life Is Beautiful","Grave of the Fireflies","Seven Samurai","Cinema Paradiso"],"xaxis":"x","y":[8.708,8.705,8.589,8.571,8.546,8.545,8.54,8.515,8.514,8.509,8.505,8.488,8.476,8.476,8.47,8.466,8.455,8.454,8.453,8.448],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parc ...

# %% [markdown]
# ## Time Series Analysis

# %% [markdown]
# ### Trend over the years

# %%
def plot_timeseries_over_years(feature: str, df: pd.DataFrame):
    time_series_data = df.groupby('release_year').agg({feature: 'mean'}).reset_index()
    fig_popularity = px.line(time_series_data, x='release_year', y= feature, title=f'{feature.title()} Over the Years')
    fig_popularity.show()

# %%
time_series_features = ['popularity', 'vote_count', 'vote_average']
for feature in time_series_features:
    plot_timeseries_over_years(feature, df)
# Out:
# <div>                            <div id="1d6e38ca-eb94-4814-8e42-c82154d3523f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d6e38ca-eb94-4814-8e42-c82154d3523f")) {                    Plotly.newPlot(                        "1d6e38ca-eb94-4814-8e42-c82154d3523f",                        [{"hovertemplate":"release_year=%{x}\u003cbr\u003epopularity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[1902,1903,1915,1916,1920,1921,1922,1923,1924,1925,1926,1927,1928,1929,1930,1931,1932,1933,1934,1935,1936,1937,1938,1939,1940,1941,1942,1943,1944,1945,1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023],"xaxis":"x","y":[25.615,13.882,17.163,10.373,20.384,19.14,32.842,15.95,16.047,15.819666666666665,15.540000000000001,20.8525,15.208,17.314,31.71,21.7714,20.2495,20.21225,15.21175,18.84375,18.121,42.5345,21.12475,31.78516666666667,27.325555555555557,27.593875,24.505333333333336,19.515,17.7255,15.773499999999999,22.02518181818182,22.61171428571428,20.128,18.524833333333333,25.947555555555553,27.465555555555554,20.76457142857143,20.381625,23.6709375,20.473875,23.884533333333334,22.6574,21.3671,26.944357142857143,21.61181818181818,22.457882352941176,21.429679999999998,24.631695652173914,22.664136363636363,24.218285714285713,23.454791666666665,23.612045454545456,25.909464285714286,21.7206875,22.714894736842105,22.119944444444442,26.809961538461536,22.928052631578947,24.730172413793102,22.576375,24.035416666666666,27.24896551724138,24.767861111111113,29.5420625,23.772227272727275,24.53238,24.54927450980392,27.65287234042553,27.580111111111112,27.85664788732394,26.462357142857144,26.580850746268656,25.540100000000002,28.748868421052634,30.68543373493976,29.318154929577464,29.378336956521736,29
1920,1921,1922,1923,1924,1925,1926,1927,1928,1929,1930,1931,1932,1933,1934,1935,1936,1937,1938,1939,1940,1941,1942,1943,1944,1945,1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023],"xaxis":"x","y":[7.9,7.008,6.034,7.103,8.0,8.193,7.715,7.839,8.09,7.585999999999999,7.942,7.9985,7.80625,7.5,7.748,7.669200000000001,7.34725,7.3,7.32425,7.41425,7.773333333333333,7.49,7.49475,7.694500000000001,7.647333333333332,7.35175,6.969666666666666,7.7595,7.369125,7.5812,7.569818181818182,7.307714285714286,7.70625,7.446000000000001,7.741777777777778,7.333444444444445,7.811571428571428,7.31375,7.5085,7.478,7.445866666666666,7.800933333333333,7.3563,7.363714285714286,7.569772727272727,7.561588235294117,7.680879999999999,7.3627391304347825,7.4588636363636365,7.3689285714285715,7.418666666666667,7.2530909090909095,7.164321428571428,7.1419375,7.138947368421052,7.1616388888888896,7.143423076923076,7.2277894736842105,7.17844827586207,7.325583333333333,7.186958333333333,6.9477586206896556,6.780652777777778,7.06425,6.868909090909091,6.8706000000000005,6.837666666666666,6.7894893617021275,6.764142857142858,6.709197183098592,6.7578,6.784768656716418,6.7477374999999995,6.711605263157895,6.56555421686747,6.7437746478873235,6.646445652173912,6.743093457943925,6.631564356435644,6.716129310344828,6.4757678571428565,6.602093023255813,6.6592442748091605,6.6243255813953486,6.516084507042254,6.542029411764706,6.46056647398844,6.460322222222222,6.530977157360406,6.462834146341464,6.432261224489796,6.496818548387097,6.436642276422764,6.462798534798535,6.458866666666666,6.430514950166113,6.414501915708812,6.4801190476190484,6.481947075208913,6.435797965116278,6.453983425414365,6.482416883116883,6.592764705882353,6.7638390804597694,6.715047272727272,6.852743902439024,6.877279661016949,6.974588983050847],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2 ...

# %% [markdown]
# ### Trend over months

# %%
def plot_timeseries_over_months(feature: str, df: pd.DataFrame):
    time_series_data = df.groupby('release_month').agg({feature: 'mean'}).reset_index()
    # Set the categorical order for the months
    time_series_data['release_month'] = pd.Categorical(time_series_data['release_month'],
                                                   categories=['January', 'February', 'March', 'April', 'May', 'June', 
                                                               'July', 'August', 'September', 'October', 'November', 'December'],
                                                   ordered=True)
    # Sort the DataFrame by the categorical order
    time_series_data = time_series_data.sort_values('release_month')
    fig_popularity = px.line(time_series_data, x='release_month', y= feature, title=f'{feature.title()} Over the Months')
    fig_popularity.show()

# %%
df['release_month'].unique()
# Out:
# array(['October', 'March', 'June', 'July', 'February', 'August',
#        'January', 'December', 'May', 'November', 'September', 'April'],
#       dtype=object)

# %%
time_series_features = ['popularity', 'vote_count', 'vote_average']
for feature in time_series_features:
    plot_timeseries_over_months(feature, df)
# Out:
# <div>                            <div id="2e509a78-e5d3-4d68-9ed2-6d682fa5aabf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2e509a78-e5d3-4d68-9ed2-6d682fa5aabf")) {                    Plotly.newPlot(                        "2e509a78-e5d3-4d68-9ed2-6d682fa5aabf",                        [{"hovertemplate":"release_month=%{x}\u003cbr\u003epopularity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["January","February","March","April","May","June","July","August","September","October","November","December"],"xaxis":"x","y":[27.855078947368423,28.55084146341463,32.086122191011235,30.372124183006537,36.58294710743802,38.025838108882525,40.584801749271136,33.27133552631579,30.87852684903749,30.5505910543131,36.15145609065156,31.106093784078517],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"}, ...
# <div>                            <div id="0b1f32a9-c26d-4074-a855-7bb2764d59bb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0b1f32a9-c26d-4074-a855-7bb2764d59bb")) {                    Plotly.newPlot(                        "0b1f32a9-c26d-4074-a855-7bb2764d59bb",                        [{"hovertemplate":"release_month=%{x}\u003cbr\u003evote_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["January","February","March","April","May","June","July","August","September","October","November","December"],"xaxis":"x","y":[1324.8035714285713,1710.4131097560976,1854.9543539325844,1785.8300653594772,2613.729752066116,2635.10888252149,2349.3972303206997,1491.8578947368421,1582.1707193515704,1834.3051118210863,2260.731586402266,2242.9394765539805],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f ...
# <div>                            <div id="b47fb484-305e-49a3-bb16-675db8e068df" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b47fb484-305e-49a3-bb16-675db8e068df")) {                    Plotly.newPlot(                        "b47fb484-305e-49a3-bb16-675db8e068df",                        [{"hovertemplate":"release_month=%{x}\u003cbr\u003evote_average=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["January","February","March","April","May","June","July","August","September","October","November","December"],"xaxis":"x","y":[6.480335526315789,6.542545731707317,6.599328651685393,6.511999183006536,6.687874380165289,6.67047134670487,6.601162536443149,6.575909210526316,6.691341945288754,6.644644302449414,6.7363675637393765,6.801613958560523],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"er ...

# %% [markdown]
# ## Building Recommendation System

# %% [markdown]
# > ### 1. Recommendation based on weighted rating
# We can use the average ratings of the movie as the score but using this won't be fair enough since a movie with 8.9 average rating and only 3 votes cannot be considered better than the movie with 7.8 as as average rating but 40 vo

# %% [markdown]
# <img src="attachment:51531988-4078-400c-ab35-c3865c8dbf04.png" width="600px" height="400px">
#
# [***QUORA LINK***](https://www.kaggle.com/)
#
# [**IMDB Top 250 Movies**](https://m.imdb.com/chart/top/)

# %%
def weighted_rating(df, m, C):
    v = df['vote_count']
    R = df['vote_average']
    return (v / (v+m) * R )+ (m / (m + v) * C)

# Calculate C (mean of vote_average)
C = df['vote_average'].mean()

# Define m (minimum votes required)
m = df['vote_count'].quantile(0.60)
# 60% of the datapoints exist with vote_count <=m 

# Filter movies that qualify for the chart
qualified_movies = df[df['vote_count'] >= m].copy()

# Calculate the weighted rating
qualified_movies['score'] = weighted_rating(qualified_movies, m, C)

# Sort movies based on score
recommended_movies = qualified_movies.sort_values('score', ascending=False)

print(recommended_movies[['title', 'score']])
# Out:
#                          title     score
# 121   The Shawshank Redemption  8.614463
# 120              The Godfather  8.590342
# 128            The Dark Knight  8.447121
# 123           Schindler's List  8.432368
# 122      The Godfather Part II  8.411954
# ...                        ...       ...
# 19              The Open House  5.080592
# 8808                Death Note  4.798954
# 8796            Batman & Robin  4.789835
# 8783            Fantastic Four  4.788865
# 8829      Dragonball Evolution  4.288819
#
# [3525 rows x 2 columns]

# %% [markdown]
# > ### 2. Recommendation based on title and overview

# %%
df = df[['id','title', 'overview']]
df
# Out:
#         id                                 title  \
# 0   168705                            BloodRayne
# 1    19766                    Inspector Gadget 2
# 2   248705            The Visitors: Bastille Day
# 3    17711  The Adventures of Rocky & Bullwinkle
# 4      580                     Jaws: The Revenge
# ..     ...                                   ...
# 15  505642        Black Panther: Wakanda Forever
# 16  635910        The Last Voyage of the Demeter
# 17  670292                           The Creator
# 18  817758                                   TÁR
# 19  949423                                 Pearl
#
#                                              overview
# 0   In 18th-century Romania, after spending much o...
# 1   After capturing Claw, all the criminals have g...
# 2   Stuck in the corridors of time, Godefroy de Mo...
# 3   Rocky and Bullwinkle have been living off the ...
# 4   After another deadly shark attack, Ellen Brody...
# ..                                                ...
# 15  Queen Ramonda, Shuri, M’Baku, Okoye and the Do...
# 16  The crew of the merchant ship Demeter attempts...
# 17  Amid a future war between the human race and t...
# 18  Renowned musician Lydia Tár is days away from ...
# 19  Trapped on her family’s isolated farm, Pearl m...
#
# [8810 rows x 3 columns]

# %% [markdown]
# #### Text Preprocessing
# [ref notebook](https://www.kaggle.com/code/sudalairajkumar/getting-started-with-text-preprocessing)

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from wordcloud import WordCloud
from nltk.stem import WordNetLemmatizer
import string, nltk

# %%
# !unzip /usr/share/nltk_data/corpora/wordnet.zip -d /usr/share/nltk_data/corpora/
# Out:
# Archive:  /usr/share/nltk_data/corpora/wordnet.zip
#    creating: /usr/share/nltk_data/corpora/wordnet/
#   inflating: /usr/share/nltk_data/corpora/wordnet/lexnames
#   inflating: /usr/share/nltk_data/corpora/wordnet/data.verb
#   inflating: /usr/share/nltk_data/corpora/wordnet/index.adv
#   inflating: /usr/share/nltk_data/corpora/wordnet/adv.exc
#   inflating: /usr/share/nltk_data/corpora/wordnet/index.verb
#   inflating: /usr/share/nltk_data/corpora/wordnet/cntlist.rev
#   inflating: /usr/share/nltk_data/corpora/wordnet/data.adj
#   inflating: /usr/share/nltk_data/corpora/wordnet/index.adj
#   inflating: /usr/share/nltk_data/corpora/wordnet/LICENSE
#   inflating: /usr/share/nltk_data/corpora/wordnet/citation.bib
#   inflating: /usr/share/nltk_data/corpora/wordnet/noun.exc
#   inflating: /usr/share/nltk_data/corpora/wordnet/verb.exc
#   inflating: /usr/share/nltk_data/corpora/wordnet/README
#   inflating: /usr/share/nltk_data/corpora/wordnet/index.sense
#   inflating: /usr/share/nltk_data/corpora/wordnet/data.noun
#   inflating: /usr/share/nltk_data/corpora/wordnet/data.adv
#   inflating: /usr/share/nltk_data/corpora/wordnet/index.noun
#   inflating: /usr/share/nltk_data/corpora/wordnet/adj.exc

# %%
import re
stop_words = stopwords.words('english')
lemma = WordNetLemmatizer()
def preprocess(message: str):
    # Remove possessive suffixes
    message = re.sub(r"\b(\w+)'s\b", r'\1', message)
    message = re.sub(r"\b(\w+)s'\b", r'\1', message)
    
    words = message.lower()
    words = word_tokenize(words)
    words = ' '.join(process_words(words))
    return words
    

def process_words(words):
    res = []
    for word in words:
        if word not in string.punctuation \
        and len(word)>1 \
        and word not in stop_words: 
            lemma_word = lemma.lemmatize(word)
            if len(lemma_word) > 1:
                res.append(lemma_word)                
    
    return res

# %%
from tqdm.notebook import tqdm
tqdm.pandas(desc="Processing")
df['processed_overview'] = df['overview'].progress_apply(preprocess)
df
# Out:
# Processing:   0%|          | 0/8810 [00:00<?, ?it/s]
#         id                                 title  \
# 0   168705                            BloodRayne
# 1    19766                    Inspector Gadget 2
# 2   248705            The Visitors: Bastille Day
# 3    17711  The Adventures of Rocky & Bullwinkle
# 4      580                     Jaws: The Revenge
# ..     ...                                   ...
# 15  505642        Black Panther: Wakanda Forever
# 16  635910        The Last Voyage of the Demeter
# 17  670292                           The Creator
# 18  817758                                   TÁR
# 19  949423                                 Pearl
#
#                                              overview  \
# 0   In 18th-century Romania, after spending much o...
# 1   After capturing Claw, all the criminals have g...
# 2   Stuck in the corridors of time, Godefroy de Mo...
# 3   Rocky and Bullwinkle have been living off the ...
# 4   After another deadly shark attack, Ellen Brody...
# ..                                                ...
# 15  Queen Ramonda, Shuri, M’Baku, Okoye and the Do...
# 16  The crew of the merchant ship Demeter attempts...
# 17  Amid a future war between the human race and t...
# 18  Renowned musician Lydia Tár is days away from ...
# 19  Trapped on her family’s isolated farm, Pearl m...
#
#                                    processed_overview
# 0   18th-century romania spending much life travel...
# 1   capturing claw criminal gone hiding claw escap...
# 2   stuck corridor time godefroy de montmirail fai...
# 3   rocky bullwinkle living finance made rerun car...
# 4   another deadly shark attack ellen brody decide...
# ..                                                ...
# 15  queen ramonda shuri baku okoye dora milaje fig...
# 16  crew merchant ship demeter attempt survive oce...
# 17  amid future war human race force artificial in...
# 18  renowned musician lydia tár day away recording...
# 19  trapped family isolated farm pearl must tend a...
#
# [8810 rows x 4 columns]

# %%
from wordcloud import WordCloud
text = ' '.join(df['overview'])
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Word Cloud for Movie Overviews')
plt.axis('off')
plt.show()

# %% [markdown]
# ***After Preprocessing...***

# %%
from wordcloud import WordCloud
text = ' '.join(df['processed_overview'])
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Word Cloud for processed Movie Overviews')
plt.axis('off')
plt.show()

# %%
df['processed_overview'].isna().sum()
# Out:
# 0

# %% [markdown]
# Combining both the `title` and `overview` of movies to create a richer feature set can indeed improve the quality of clustering. By using both the title and the overview, you provide the model with more context, which can lead to better differentiation between clusters.

# %% [markdown]
# #### Using Jaccard Similarity

# %%
df['text'] = df['title'].str.lower() + ' ' + df['processed_overview']
df = df.reset_index(drop=True)

# %%
df
# Out:
#           id                                 title  \
# 0     168705                            BloodRayne
# 1      19766                    Inspector Gadget 2
# 2     248705            The Visitors: Bastille Day
# 3      17711  The Adventures of Rocky & Bullwinkle
# 4        580                     Jaws: The Revenge
# ...      ...                                   ...
# 8805  505642        Black Panther: Wakanda Forever
# 8806  635910        The Last Voyage of the Demeter
# 8807  670292                           The Creator
# 8808  817758                                   TÁR
# 8809  949423                                 Pearl
#
#                                                overview  \
# 0     In 18th-century Romania, after spending much o...
# 1     After capturing Claw, all the criminals have g...
# 2     Stuck in the corridors of time, Godefroy de Mo...
# 3     Rocky and Bullwinkle have been living off the ...
# 4     After another deadly shark attack, Ellen Brody...
# ...                                                 ...
# 8805  Queen Ramonda, Shuri, M’Baku, Okoye and the Do...
# 8806  The crew of the merchant ship Demeter attempts...
# 8807  Amid a future war between the human race and t...
# 8808  Renowned musician Lydia Tár is days away from ...
# 8809  Trapped on her family’s isolated farm, Pearl m...
#
#                                      processed_overview  \
# 0     18th-century romania spending much life travel...
# 1     capturing claw criminal gone hiding claw escap...
# 2     stuck corridor time godefroy de montmirail fai...
# 3     rocky bullwinkle living finance made rerun car...
# 4     another deadly shark attack ellen brody decide...
# ...                                                 ...
# 8805  queen ramonda shuri baku okoye dora milaje fig...
# 8806  crew merchant ship demeter attempt survive oce...
# 8807  amid future war human race force artificial in...
# 8808  renowned musician lydia tár day away recording...
# 8809  trapped family isolated farm pearl must tend a...
#
#                                                    text
# 0     bloodrayne 18th-century romania spending much ...
# 1     inspector gadget 2 capturing claw criminal gon...
# 2     the visitors: bastille day stuck corridor time...
# 3     the adventures of rocky & bullwinkle rocky bul...
# 4     jaws: the revenge another deadly shark attack ...
# ...                                                 ...
# 8805  black panther: wakanda forever queen ramonda s...
# 8806  the last voyage of the demeter crew merchant s...
# 8807  the creator amid future war human race force a...
# 8808  tár renowned musician lydia tár day away recor...
# 8809  pearl trapped family isolated farm pearl must ...
#
# [8810 rows x 5 columns]

# %%
text = ' '.join(df['text'])
# Tokenize the concatenated string to extract unique words
tokens = word_tokenize(text)  # Tokenize and convert to lowercase
# Get unique words
unique_words = set(tokens)

print(f'Total tokens: {len(tokens)}, unique tokens: {len(unique_words)}')
# Out:
# Total tokens: 259368, unique tokens: 28355

# %%
encoding_dict = {token: i for i,token in enumerate(unique_words)}
list(encoding_dict.items())[:5]
# Out:
# [('golfer', 0), ('deepening', 1), ('silverback', 2), ('corinth', 3), ('³', 4)]

# %%
def encode_row(row):
    overview = row['text']
    tokens = word_tokenize(overview)
    encoded_tokens = [encoding_dict[token] for token in tokens]
    return encoded_tokens

# Apply encoding to each row
tqdm.pandas(desc="Encoding")
df['encoded_tokens'] = df.progress_apply(encode_row, axis=1)
# Out:
# Encoding:   0%|          | 0/8810 [00:00<?, ?it/s]

# %%
df[['text', 'encoded_tokens']]
# Out:
#                                                    text  \
# 0     bloodrayne 18th-century romania spending much ...
# 1     inspector gadget 2 capturing claw criminal gon...
# 2     the visitors: bastille day stuck corridor time...
# 3     the adventures of rocky & bullwinkle rocky bul...
# 4     jaws: the revenge another deadly shark attack ...
# ...                                                 ...
# 8805  black panther: wakanda forever queen ramonda s...
# 8806  the last voyage of the demeter crew merchant s...
# 8807  the creator amid future war human race force a...
# 8808  tár renowned musician lydia tár day away recor...
# 8809  pearl trapped family isolated farm pearl must ...
#
#                                          encoded_tokens
# 0     [187, 20489, 6186, 11775, 23493, 3752, 19430, ...
# 1     [21278, 22365, 19170, 16484, 22261, 24125, 190...
# 2     [1993, 20488, 2103, 25231, 17232, 12656, 5754,...
# 3     [1993, 19176, 13705, 16667, 23566, 7908, 16667...
# 4     [11090, 2103, 1993, 11362, 25941, 12602, 21112...
# ...                                                 ...
# 8805  [6824, 27017, 2103, 8166, 4048, 26902, 9455, 2...
# 8806  [1993, 1630, 12350, 13705, 1993, 5359, 25624, ...
# 8807  [1993, 12158, 25055, 25848, 7627, 17104, 4026,...
# 8808  [25217, 15761, 15437, 14036, 25217, 17232, 136...
# 8809  [26228, 11308, 12395, 20593, 16875, 26228, 231...
#
# [8810 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['id', 'title', 'overview', 'processed_overview', 'text',
#        'encoded_tokens'],
#       dtype='object')

# %%
df['unique_key'] = df['title'].str.lower() + '_' + df.index.astype(str)
indices = pd.Series(df.index, index=df['unique_key'])
len(indices)
# Out:
# 8810

# %%
df
# Out:
#           id                                 title  \
# 0     168705                            BloodRayne
# 1      19766                    Inspector Gadget 2
# 2     248705            The Visitors: Bastille Day
# 3      17711  The Adventures of Rocky & Bullwinkle
# 4        580                     Jaws: The Revenge
# ...      ...                                   ...
# 8805  505642        Black Panther: Wakanda Forever
# 8806  635910        The Last Voyage of the Demeter
# 8807  670292                           The Creator
# 8808  817758                                   TÁR
# 8809  949423                                 Pearl
#
#                                                overview  \
# 0     In 18th-century Romania, after spending much o...
# 1     After capturing Claw, all the criminals have g...
# 2     Stuck in the corridors of time, Godefroy de Mo...
# 3     Rocky and Bullwinkle have been living off the ...
# 4     After another deadly shark attack, Ellen Brody...
# ...                                                 ...
# 8805  Queen Ramonda, Shuri, M’Baku, Okoye and the Do...
# 8806  The crew of the merchant ship Demeter attempts...
# 8807  Amid a future war between the human race and t...
# 8808  Renowned musician Lydia Tár is days away from ...
# 8809  Trapped on her family’s isolated farm, Pearl m...
#
#                                      processed_overview  \
# 0     18th-century romania spending much life travel...
# 1     capturing claw criminal gone hiding claw escap...
# 2     stuck corridor time godefroy de montmirail fai...
# 3     rocky bullwinkle living finance made rerun car...
# 4     another deadly shark attack ellen brody decide...
# ...                                                 ...
# 8805  queen ramonda shuri baku okoye dora milaje fig...
# 8806  crew merchant ship demeter attempt survive oce...
# 8807  amid future war human race force artificial in...
# 8808  renowned musician lydia tár day away recording...
# 8809  trapped family isolated farm pearl must tend a...
#
#                                                    text  \
# 0     bloodrayne 18th-century romania spending much ...
# 1     inspector gadget 2 capturing claw criminal gon...
# 2     the visitors: bastille day stuck corridor time...
# 3     the adventures of rocky & bullwinkle rocky bul...
# 4     jaws: the revenge another deadly shark attack ...
# ...                                                 ...
# 8805  black panther: wakanda forever queen ramonda s...
# 8806  the last voyage of the demeter crew merchant s...
# 8807  the creator amid future war human race force a...
# 8808  tár renowned musician lydia tár day away recor...
# 8809  pearl trapped family isolated farm pearl must ...
#
#                                          encoded_tokens  \
# 0     [187, 20489, 6186, 11775, 23493, 3752, 19430, ...
# 1     [21278, 22365, 19170, 16484, 22261, 24125, 190...
# 2     [1993, 20488, 2103, 25231, 17232, 12656, 5754,...
# 3     [1993, 19176, 13705, 16667, 23566, 7908, 16667...
# 4     [11090, 2103, 1993, 11362, 25941, 12602, 21112...
# ...                                                 ...
# 8805  [6824, 27017, 2103, 8166, 4048, 26902, 9455, 2...
# 8806  [1993, 1630, 12350, 13705, 1993, 5359, 25624, ...
# 8807  [1993, 12158, 25055, 25848, 7627, 17104, 4026,...
# 8808  [25217, 15761, 15437, 14036, 25217, 17232, 136...
# 8809  [26228, 11308, 12395, 20593, 16875, 26228, 231...
#
#                                   unique_key
# 0                               bloodrayne_0
# 1                       inspector gadget 2_1
# 2               the visitors: bastille day_2
# 3     the adventures of rocky & bullwinkle_3
# 4                        jaws: the revenge_4
# ...                                      ...
# 8805     black panther: wakanda forever_8805
# 8806     the last voyage of the demeter_8806
# 8807                        the creator_8807
# 8808                                tár_8808
# 8809                              pearl_8809
#
# [8810 rows x 7 columns]

# %%
# Create a dictionary mapping unique keys to titles
unique_key_to_title = {unique_key: title for unique_key, title in zip(df['unique_key'], df['title'])}
list(unique_key_to_title.items())[:5]
# Out:
# [('bloodrayne_0', 'BloodRayne'),
#  ('inspector gadget 2_1', 'Inspector Gadget 2'),
#  ('the visitors: bastille day_2', 'The Visitors: Bastille Day'),
#  ('the adventures of rocky & bullwinkle_3',
#   'The Adventures of Rocky & Bullwinkle'),
#  ('jaws: the revenge_4', 'Jaws: The Revenge')]

# %%
df.columns
# Out:
# Index(['id', 'title', 'overview', 'processed_overview', 'text',
#        'encoded_tokens', 'unique_key'],
#       dtype='object')

# %%
def get_jaccard_recommendations(title: str, df: pd.DataFrame, indices: [], key_to_title: dict):
    # Get the index of the movie that matches the title
    idx = indices[title]
    sim_scores = get_similarity_scores(idx, df)
    # Sort scores in descending order based on similarity score
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)[:10]
    print(f'Sim Scores: {sim_scores}')
    # Get indices of top 10 similar movies
    top_indices = [x[0] for x in sim_scores]
    # Getting the unique titles
    unique_titles = df['unique_key'].iloc[top_indices].tolist()
    print(unique_titles)
    # Return titles of top 10 similar movies
    return [key_to_title[title] for title in unique_titles]

# %%
# Calculate scores with all other movies
def get_similarity_scores(index: int, df: pd.DataFrame):
    similarity_matrix = []
    for i in range(len(df)):
        if i!=index:
            sim_score = calculate_jaccard_simlarity(set(df.iloc[index].iloc[6]), set(df.iloc[i].iloc[6]))
            similarity_matrix.append((i, sim_score))
    
    return similarity_matrix

# %%
def calculate_jaccard_simlarity(set1, set2):
    intersection = len(set1.intersection(set2))
    union = len(set1.union(set2))
    return intersection / union if union != 0 else 0  # Handle case where union is 0

# %% [markdown]
# #### Predict

# %% [markdown]
# ***Just Cross Checking***

# %%
df[df['title']=='The Dark Knight']
# Out:
#       id            title                                           overview  \
# 127  155  The Dark Knight  Batman raises the stakes in his war on crime. ...
#
#                                     processed_overview  \
# 127  batman raise stake war crime help lt. jim gord...
#
#                                                   text  \
# 127  the dark knight batman raise stake war crime h...
#
#                                         encoded_tokens           unique_key
# 127  [1993, 7264, 16314, 12748, 27203, 17549, 7627,...  the dark knight_127

# %%
indices['the dark knight_127']
# Out:
# 127

# %%
movie_title = 'the dark knight_127'
recommendations = get_jaccard_recommendations(movie_title, df, indices, unique_key_to_title)
print(f"Top 10 movies similar to '{movie_title}':")
print(recommendations)
# Out:
# Sim Scores: [(2217, 0.875), (713, 0.8235294117647058), (2758, 0.7647058823529411), (6717, 0.7647058823529411), (7171, 0.7333333333333333), (7722, 0.7333333333333333), (2117, 0.7222222222222222), (2118, 0.7222222222222222), (4112, 0.7222222222222222), (4732, 0.7222222222222222)]
# ['the wandering earth ii_2217', 'the dark knight rises_713', 'the king and i_2758', 'the midnight meat train_6717', 'die hart_7171', 'in the earth_7722', 'the ladykillers_2117', 'a shot in the dark_2118', 'the ghost and the darkness_4112', 'the wandering earth_4732']
# Top 10 movies similar to 'the dark knight_127':
# ['The Wandering Earth II', 'The Dark Knight Rises', 'The King and I', 'The Midnight Meat Train', 'Die Hart', 'In the Earth', 'The Ladykillers', 'A Shot in the Dark', 'The Ghost and the Darkness', 'The Wandering Earth']

# %% [markdown]
# #### Cosine Similarity
# - We see that over 23,000 different words were used to describe the 4800 movies in our dataset.
# - We will be using the cosine similarity to calculate a numeric quantity that denotes the similarity between two movies. We use the cosine similarity score since it is independent of magnitude and is relatively easy and fast to calculate. Mathematically, it is defined as follows:
#
# ![image.png](attachment:e6b04e14-cd74-413f-9fef-8ccd9076ca6a.png)
#
# ***Note***
# - Since we have used the TF-IDF vectorizer, calculating the dot product will directly give us the cosine similarity score.
# - Therefore, we will use sklearn's linear_kernel() instead of cosine_similarities() since it is faster.
#
# <img src="attachment:2254cf7e-3f08-4686-a695-9d2e7d20b187.png" width="600px" height="400px">

# %%
# Function that takes in movie title as input and outputs most similar movies
def get_recommendations(title, cosine_sim, df: pd.DataFrame, indices):
    # Get the index of the movie that matches the title
    idx = indices[title]

    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:11]

    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar movies
    return df['title'].iloc[movie_indices]

# %% [markdown]
# #### Using TFIDF

# %%
#Import TfIdfVectorizer from scikit-learn

#Define a TF-IDF Vectorizer Object. Remove all english stop words such as 'the', 'a'
tfidf = TfidfVectorizer(stop_words='english')

df['processed_text'] = df['text'].fillna('')

# Step 1: Construct the required TF-IDF matrix by fitting and transforming the data
tfidf_matrix = tfidf.fit_transform(df['processed_text'])

#Output the shape of tfidf_matrix
print(f'TFIDF matrix shape: {tfidf_matrix.shape}')

# Step 2: Compute the cosine similarity matrix
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)
# Out:
# TFIDF matrix shape: (8810, 25097)

# %%
movie_title = 'the dark knight_127'
recommendations = get_recommendations(movie_title, cosine_sim = cosine_sim, df = df, indices = indices)
print(f"Top 10 movies similar to '{movie_title}':")
print(recommendations)
# Out:
# Top 10 movies similar to 'the dark knight_127':
# 1484       Batman: The Long Halloween, Part Two
# 1353       Batman: The Long Halloween, Part One
# 713                       The Dark Knight Rises
# 2277                                     Batman
# 483     Batman: The Dark Knight Returns, Part 2
# 1338               Batman: Mask of the Phantasm
# 792     Batman: The Dark Knight Returns, Part 1
# 4728                   Batman: The Killing Joke
# 4444                 Batman: Gotham by Gaslight
# 854                                  The Batman
# Name: title, dtype: object

# %% [markdown]
# #### Using Countvectorizer

# %%
count_vectorizer = CountVectorizer()

# Fit and transform the text data
count_matrix = count_vectorizer.fit_transform(df['processed_text'])

# Compute cosine similarity on the count_matrix
cosine_sim = cosine_similarity(count_matrix, count_matrix)

# %%
movie_title = 'the dark knight_127'
recommendations = get_recommendations(movie_title, cosine_sim = cosine_sim, df = df, indices = indices)
print(f"Top 10 movies similar to '{movie_title}':")
print(recommendations)
# Out:
# Top 10 movies similar to 'the dark knight_127':
# 713                       The Dark Knight Rises
# 1484       Batman: The Long Halloween, Part Two
# 1338               Batman: Mask of the Phantasm
# 1353       Batman: The Long Halloween, Part One
# 2277                                     Batman
# 792     Batman: The Dark Knight Returns, Part 1
# 854                                  The Batman
# 483     Batman: The Dark Knight Returns, Part 2
# 4728                   Batman: The Killing Joke
# 4444                 Batman: Gotham by Gaslight
# Name: title, dtype: object

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The movie recommendation system leverages weighted ratings and cosine similarity, combined with extensive exploratory data analysis (EDA) and multiple approaches, to accurately recommend films. By addressing title duplicates and ensuring unique identifiers, the system effectively matches user preferences with similar movies, enhancing the overall recommendation accuracy and user satisfaction
